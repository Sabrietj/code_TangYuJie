# %%
import pandas as pd
from datetime import datetime

if __name__ == '__main__':
    file_path = "/root/autodl-fs/processed_data/CIC-IDS-2017-session-srcIP_srcPort_dstIP_dstPort_proto/Monday-WorkingHours/Monday-WorkingHours-flow.csv"

    df = pd.read_csv(file_path, low_memory=False)
    first_row = df.iloc[0]
    last_row = df.iloc[-1]

    # 将浮点数时间戳转换为datetime
    first_time = datetime.fromtimestamp(first_row['conn.ts'])
    last_time = datetime.fromtimestamp(last_row['conn.ts'])

    print(f"格式化: {first_time.strftime('%Y年%m月%d日 %H:%M:%S')}")
    print(f"格式化: {last_time.strftime('%Y年%m月%d日 %H:%M:%S')}")

    file_path = "/root/autodl-fs/processed_data/CIC-IDS-2017-session-srcIP_srcPort_dstIP_dstPort_proto/Tuesday-WorkingHours/Tuesday-WorkingHours-flow.csv"

    df = pd.read_csv(file_path, low_memory=False)
    first_row = df.iloc[0]
    last_row = df.iloc[-1]

    first_time = datetime.fromtimestamp(first_row['conn.ts'])
    last_time = datetime.fromtimestamp(last_row['conn.ts'])

    print(f"格式化: {first_time.strftime('%Y年%m月%d日 %H:%M:%S')}")
    print(f"格式化: {last_time.strftime('%Y年%m月%d日 %H:%M:%S')}")

    file_path = "/root/autodl-fs/processed_data/CIC-IDS-2017-session-srcIP_srcPort_dstIP_dstPort_proto/Wednesday-WorkingHours/Wednesday-WorkingHours-flow.csv"

    df = pd.read_csv(file_path, low_memory=False)
    first_row = df.iloc[0]
    last_row = df.iloc[-1]

    first_time = datetime.fromtimestamp(first_row['conn.ts'])
    last_time = datetime.fromtimestamp(last_row['conn.ts'])

    print(f"格式化: {first_time.strftime('%Y年%m月%d日 %H:%M:%S')}")
    print(f"格式化: {last_time.strftime('%Y年%m月%d日 %H:%M:%S')}")

    file_path = "/root/autodl-fs/processed_data/CIC-IDS-2017-session-srcIP_srcPort_dstIP_dstPort_proto/Thursday-WorkingHours/Thursday-WorkingHours-flow.csv"

    df = pd.read_csv(file_path, low_memory=False)
    first_row = df.iloc[0]
    last_row = df.iloc[-1]

    first_time = datetime.fromtimestamp(first_row['conn.ts'] )
    last_time = datetime.fromtimestamp(last_row['conn.ts'] )

    print(f"格式化: {first_time.strftime('%Y年%m月%d日 %H:%M:%S')}")
    print(f"格式化: {last_time.strftime('%Y年%m月%d日 %H:%M:%S')}")

    file_path = "/root/autodl-fs/processed_data/CIC-IDS-2017-session-srcIP_srcPort_dstIP_dstPort_proto/Friday-WorkingHours/Friday-WorkingHours-flow.csv"

    df = pd.read_csv(file_path, low_memory=False)
    first_row = df.iloc[0]
    last_row = df.iloc[-1]

    first_time = datetime.fromtimestamp(first_row['conn.ts'] )
    last_time = datetime.fromtimestamp(last_row['conn.ts'] )

    print(f"格式化: {first_time.strftime('%Y年%m月%d日 %H:%M:%S')}")
    print(f"格式化: {last_time.strftime('%Y年%m月%d日 %H:%M:%S')}")

# %%
import os

# 查看当前工作目录
print("当前工作目录:", os.getcwd())

# 列出当前目录下的文件和文件夹
print("目录内容:")
for item in os.listdir():
    print(f"  - {item}")
# Out:
# 当前工作目录: /tmp/pycharm_project_398/code_TangYuJie/src/extract_feature
# 目录内容:
#   - analyze_log.py
#   - evaluate_data.py
#   - flow_stats.py
#   - label_log.py
#   - print_manager.py
#   - process_log.py
#   - read_file.py
#   - session_tuple.py
#   - __label__.py
#   - __main__.py
#   - __pycache__
#   - 1.py
#   - test.ipynb
