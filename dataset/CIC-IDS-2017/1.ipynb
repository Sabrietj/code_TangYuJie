# %%
import os
print(os.getcwd())  # 当前工作目录

# %%
import pandas as pd

# 读取文件，nrows=0 表示只读取表头，不读取数据行，速度极快
df = pd.read_csv('/autodl-fs/data/CIC-IDS-2017/Friday-WorkingHours/your_file.csv', nrows=0)

# 打印所有列名（以列表形式）
print(df.columns.tolist())

# 或者直接查看
df.columns

# %%
import os

file_path = '/autodl-fs/data/CIC-IDS-2017/Friday-WorkingHours/conn_label.log'

if os.path.exists(file_path):
    print("✅ 文件存在")
else:
    print("❌ 文件不存在，请检查文件名拼写")

# %%
import pandas as pd

# 读取CSV文件的第一行（仅表头）
df = pd.read_csv('/root/autodl-fs/processed_data/CIC-IDS-2017-session-srcIP_srcPort_dstIP_dstPort_proto/Thursday-WorkingHours/Thursday-WorkingHours-session.csv', nrows=0)
print("特征名：", df.columns.tolist())

# 或者直接查看列名
print("\n特征名列表：")
for i, col in enumerate(df.columns, 1):
    print(f"{i}. {col}")


df = pd.read_csv('/root/autodl-fs/processed_data1/CIC-IDS-2017-session-srcIP_srcPort_dstIP_dstPort_proto/Thursday-WorkingHours/Thursday-WorkingHours-session.csv', nrows=0)
print("特征名：", df.columns.tolist())

# 或者直接查看列名
print("\n特征名列表：")
for i, col in enumerate(df.columns, 1):
    print(f"{i}. {col}")
# Out:
# 特征名： ['session_index', 'is_malicious', 'ssl_version', 'cipher_suite_server', 'cert_key_alg', 'cert_sig_alg', 'cert_key_type', 'max_duration', 'avg_duration', 'percent_of_std_duration', 'number_of_flows', 'ssl_flow_ratio', 'avg_size', 'recv_sent_size_ratio', 'avg_pkts', 'recv_sent_pkts_ratio', 'packet_loss', 'percent_of_established_state', 'avg_time_diff', 'std_time_diff', 'max_time_diff', 'ssl_tls_ratio', 'resumed', 'self_signed_ratio', 'avg_key_length', 'avg_cert_valid_day', 'std_cert_valid_day', 'percent_of_valid_cert', 'avg_valid_cert_percent', 'number_of_cert_serial', 'number_of_domains_in_cert', 'avg_cert_path', 'x509_ssl_ratio', 'SNI_ssl_ratio', 'is_SNIs_in_SNA_dns', 'is_CNs_in_SNA_dns', 'subject_CN_is_IP', 'subject_is_com', 'is_O_in_subject', 'is_CO_in_subject', 'is_ST_in_subject', 'is_L_in_subject', 'subject_only_CN', 'issuer_is_com', 'is_O_in_issuer', 'is_CO_in_issuer', 'is_ST_in_issuer', 'is_L_in_issuer', 'issuer_only_CN', 'avg_TTL', 'avg_domain_name_length', 'std_domain_na
# ...

# %%
import pandas as pd

# 读取CSV文件
file_path = "/root/autodl-fs/processed_data/CIC-IDS-2017-session-srcIP_srcPort_dstIP_dstPort_proto/Thursday-WorkingHours/Thursday-WorkingHours-session.csv"
df = pd.read_csv(file_path)

# 获取行数和列数
rows, columns = df.shape

print(f"行数: {rows}")
print(f"列数: {columns}")

# 读取CSV文件
file_path = "/root/autodl-fs/processed_data1/CIC-IDS-2017-session-srcIP_srcPort_dstIP_dstPort_proto/Thursday-WorkingHours/Thursday-WorkingHours-session.csv"
df = pd.read_csv(file_path)

# 获取行数和列数
rows, columns = df.shape

print(f"行数: {rows}")
print(f"列数: {columns}")
# Out:
# 行数: 118425
# 列数: 54
# 行数: 118425
# 列数: 54

# %%
import pandas as pd

# 读取CSV文件的第一行（仅表头）
df = pd.read_csv('/root/autodl-fs/processed_data/CIC-IDS-2017-session-srcIP_srcPort_dstIP_dstPort_proto/Thursday-WorkingHours/Thursday-WorkingHours-flow.csv', nrows=0)
print("特征名：", df.columns.tolist())

# 或者直接查看列名
print("\n特征名列表：")
for i, col in enumerate(df.columns, 1):
    print(f"{i}. {col}")


df = pd.read_csv('/root/autodl-fs/processed_data1/CIC-IDS-2017-session-srcIP_srcPort_dstIP_dstPort_proto/Thursday-WorkingHours/Thursday-WorkingHours-flow.csv', nrows=0)
print("特征名：", df.columns.tolist())

# 或者直接查看列名
print("\n特征名列表：")
for i, col in enumerate(df.columns, 1):
    print(f"{i}. {col}")
# Out:
# 特征名： ['uid', 'label', 'is_malicious', 'conn.ts', 'conn.uid', 'conn.id.orig_h', 'conn.id.orig_p', 'conn.id.resp_h', 'conn.id.resp_p', 'conn.proto', 'conn.service', 'conn.duration', 'conn.orig_bytes', 'conn.resp_bytes', 'conn.conn_state', 'conn.local_orig', 'conn.local_resp', 'conn.missed_bytes', 'conn.history', 'conn.orig_pkts', 'conn.orig_ip_bytes', 'conn.resp_pkts', 'conn.resp_ip_bytes', 'conn.tunnel_parents', 'flowmeter.ts', 'flowmeter.uid', 'flowmeter.id.orig_h', 'flowmeter.id.orig_p', 'flowmeter.id.resp_h', 'flowmeter.id.resp_p', 'flowmeter.proto', 'flowmeter.flow_duration', 'flowmeter.fwd_pkts_tot', 'flowmeter.bwd_pkts_tot', 'flowmeter.fwd_data_pkts_tot', 'flowmeter.bwd_data_pkts_tot', 'flowmeter.fwd_pkts_per_sec', 'flowmeter.bwd_pkts_per_sec', 'flowmeter.flow_pkts_per_sec', 'flowmeter.down_up_ratio', 'flowmeter.fwd_header_size_tot', 'flowmeter.fwd_header_size_min', 'flowmeter.fwd_header_size_max', 'flowmeter.bwd_header_size_tot', 'flowmeter.bwd_header_size_min', 'flowmeter.bwd_
# ...

# %%
import pandas as pd

paths = [
    "/root/autodl-fs/processed_data/CIC-IDS-2017-session-srcIP_srcPort_dstIP_dstPort_proto/Thursday-WorkingHours/Thursday-WorkingHours-flow.csv",
    "/root/autodl-fs/processed_data1/CIC-IDS-2017-session-srcIP_srcPort_dstIP_dstPort_proto/Thursday-WorkingHours/Thursday-WorkingHours-flow.csv"
]

for i, path in enumerate(paths, 1):
    # 分块计数，节省内存
    row_count = 0
    for chunk in pd.read_csv(path, chunksize=100000):
        row_count += len(chunk)
    print(f"文件{i}行数: {row_count}")

# %%
import pandas as pd

# 文件路径
file_path = "/root/autodl-fs/processed_data/CIC-IDS-2017-session-srcIP_srcPort_dstIP_dstPort_proto/Thursday-WorkingHours/Thursday-WorkingHours-flow.csv"

# 只读取前几行和必要的列
df_head = pd.read_csv(file_path, nrows=5)

print("前5行前12列数据:")
print(df_head.iloc[:, :12])

print("\n" + "="*50)

# 快速检查是否排序（只检查前1000行）
df_sample = pd.read_csv(file_path, nrows=1000, usecols=['conn.ts'] if 'conn.ts' in df_head.columns else [])

if 'conn.ts' in df_sample.columns:
    # 检查前1000行是否排序
    is_sorted = (df_sample['conn.ts'].diff().dropna() >= 0).all()
    print(f"\n检查前1000行是否按 'conn.ts' 升序: {'是' if is_sorted else '否'}")
else:
    print(f"\n文件没有 'conn.ts' 列")
    print(f"前几行列名: {df_head.columns[:10].tolist()}")
# Out:
# 前5行前12列数据:
#                   uid   label  is_malicious       conn.ts  conn.uid  \
# 0                 NaN  BENIGN             0  1.499342e+09       NaN
# 1  CcWtiZ1QyKlihrULK3  BENIGN             0  1.499342e+09       NaN
# 2  CcUQQ82zBHh9bvUoJd  BENIGN             0  1.499342e+09       NaN
# 3                 NaN  BENIGN             0  1.499342e+09       NaN
# 4   CuOSdUTkHAhpdUk91  BENIGN             0  1.499342e+09       NaN
#
#   conn.id.orig_h  conn.id.orig_p conn.id.resp_h  conn.id.resp_p conn.proto  \
# 0  192.168.10.14           59135   65.55.44.109             443        tcp
# 1  192.168.10.14           59135   65.55.44.109             443        tcp
# 2  192.168.10.19            5353    224.0.0.251            5353        udp
# 3  192.168.10.19            5353    224.0.0.251            5353        udp
# 4  192.168.10.19             137  192.168.10.50             137        udp
#
#   conn.service  conn.duration
# 0          ssl      60.311469
# ...

# %%
import pandas as pd

file_path = "/root/autodl-fs/processed_data/CIC-IDS-2017-session-srcIP_srcPort_dstIP_dstPort_proto/Thursday-WorkingHours/Thursday-WorkingHours-flow.csv"
df = pd.read_csv(file_path).tail(1)

print("第一行conn.ts:", df['conn.ts'])
print("最后一行conn.ts:", df['conn.ts'])

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# 设置图形大小
plt.figure(figsize=(10, 6))

# 读取并显示图片
img = mpimg.imread('/tmp/pycharm_project_172/src/models/flow_bert_multiview/logs/test_drift_accuracy_20260123_002152.png')
plt.imshow(img)
plt.axis('off')  # 关闭坐标轴
plt.show()
